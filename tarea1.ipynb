# %%
import matplotlib.pyplot as plt
from sklearn import linear_model # usando sklear para saber los valores optimos
import seaborn as sns
import numpy as np
import pandas as pd

# %%
datas = pd.read_csv("C:/Users/nsake/OneDrive/escritorio/data.csv", sep=",")

# %%
datas
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
data.plot.scatter(x="metro", y="precio")
plt.show()

# %%
regresion = linear_model.LinearRegression()

# %%
years = data["metro"].values.reshape((-1,1))

# %%
#Ahora si creamos el modelo
modelo = regresion.fit(years, data["precio"])

print("Interseccion (b)", modelo.intercept_)
#imprimos la pendiente
print("Pendiente (m)", modelo.coef_)
# Out:
# Interseccion (b) 361.25714285714287
# Pendiente (m) [5.64571429]

# %%
entrada= [[4],[8],[12],[16],[20],[24]]
predicciones = modelo.predict(entrada)
print(predicciones)
# Out:
# [383.84       406.42285714 429.00571429 451.58857143 474.17142857
#  496.75428571]

# %%
data.plot.scatter(x="metro", y="precio", label='Datos originales')
plt.scatter(entrada, predicciones, color='green')
plt.plot(entrada, predicciones, color='red', label='Línea de regresión')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()
